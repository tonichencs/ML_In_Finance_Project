# %%
import numpy as np
import pandas as pd
from google.colab import drive
from sklearn.preprocessing import StandardScaler

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
crsp = pd.read_csv("/content/drive/MyDrive/new_data.csv", index_col =0)
crsp = crsp[crsp['date'].between('2004-01-01', '2024-12-31')]
crsp["year"] = pd.to_datetime(crsp["date"]).dt.year

# %%
crsp
# Out:
#          PERMNO     cusip Ticker TradingSymbol  PERMCO  SICCD   NAICS  \
# 0         10001  36720410   EWST          EWST    7953   4920       0
# 1         10853  76017410   RENT          RENT    8738   7822       0
# 2         18761  79547710    SBF           SBF   21093   6726       0
# 3         85729  84917U10    TSA           TSA   15920   5941       0
# 4         80658  70532310   PSAI          PSAI   13126   8080       0
# ...         ...       ...    ...           ...     ...    ...     ...
# 1655277   19425  31609234   FBCV          FBCV   54581   6726  525990
# 1655278   19426  31609235   FBCG          FBCG   54581   6726  525990
# 1655279   19427  31609236   FFLC          FFLC   54581   6726  525990
# 1655280   19405  98980F10     ZI            ZI   57093   9999  513210
# 1655281   93436  88160R10   TSLA          TSLA   53453   9999  336110
#
#            MthCalDt    MthRet    sprtrn  ...         capxy      chechy  \
# 0        2004-01-30  0.010084  0.017276  ...      1.405000    2.461000
# 1        2004-01-30  0.011294  0.017276  ...      1.597000   -1.328000
# 2        2004-01-30  0.033250  0.017276  ...      2.575966   40.350690
# 3        2004-01-30  0.100260  0.017276  ...     79.472000   17.853000
# 4        2004-01-30  0.186722  0.017276  ...      2.788000   -3.880000
# ...             ...       ...       ...  ...           ...         ...
# 1655277  2024-12-31 -0.068526 -0.024990  ...     10.459333   12.598000
# 1655278  2024-12-31  0.006564 -0.024990  ...     39.272818   -3.378045
# 1655279  2024-12-31 -0.033064 -0.024990  ...      8.328222   11.878000
# 1655280  2024-12-31 -0.039305 -0.024990  ...     64.900000 -307.200000
# 1655281  2024-12-31  0.170008 -0.024990  ...  11342.000000 -152.000000
#
#               cshfdy       cshpry        dltry         dpcy    epspxy  \
# 0           2.596000     2.596000     0.000000     2.178000  0.110000
# 1          10.119000     9.600000     0.068000     0.875000  0.150000
# 2          44.996000    44.119379     0.000000     8.073828  0.686552
# 3          19.480000    18.309000   700.406000    40.710000  0.890000
# 4           7.340000     6.901000     0.059000     1.843000  0.460000
# ...              ...          ...          ...          ...       ...
# 1655277    62.096310    59.173859    47.844889    18.977556  0.049014
# 1655278    63.615902    62.955902    70.011932    40.354273  0.294773
# 1655279    62.081662    59.439305    43.502204    16.164315  0.047136
# 1655280   362.189000   361.953000     5.900000   155.500000  0.080000
# 1655281  3498.000000  3197.000000  2881.000000  5368.000000  2.230000
#
#                oibdpy         txty  year
# 0            3.678000     0.151000  2004
# 1            3.210000     0.479000  2004
# 2           58.224724     9.804276  2004
# 3          117.273000     7.653000  2004
# 4            7.984000     1.995000  2004
# ...               ...          ...   ...
# 1655277     32.005111     1.560352  2024
# 1655278    104.843432    14.175955  2024
# 1655279     27.367796     1.580070  2024
# 1655280    314.400000     2.200000  2024
# 1655281  13128.000000  1837.000000  2024
#
# [1655282 rows x 41 columns]

# %%
crsp["rsi_6"] = crsp["mom_6"]/(np.abs(crsp["mom_6"]+crsp["vol_6"]))
crsp['trend_strength'] = crsp['mom_12'] * np.sign(crsp['mom_6'])

# %%
for i in crsp.columns:
  print(i, crsp[i].isna().sum())
# Out:
# PERMNO 0
# cusip 0
# Ticker 0
# TradingSymbol 0
# PERMCO 0
# SICCD 0
# NAICS 0
# MthCalDt 0
# MthRet 0
# sprtrn 0
# date 0
# mom_12 0
# mom_6 0
# vol_12 0
# vol_6 0
# rev_1 0
# id 0
# rvol_1 0
# qmj_safety 0
# seas_11_15na 0
# ret_3_1 0
# iskew_ff3_21d 0
# rskew_21d 0
# sti_gr1a 0
# earnings_variability 0
# nfna_gr1a 0
# seas_16_20an 0
# corr_1260d 0
# resff3_12_1 0
# quarter 0
# conm 0
# capxy 0
# chechy 0
# cshfdy 0
# cshpry 0
# dltry 0
# dpcy 0
# epspxy 0
# oibdpy 0
# txty 0
# year 0
# rsi_6 0
# trend_strength 0

# %%
id_col = ["PERMNO", 'CUSIP', 'Ticker', 'SICCD','NAICS']
time_col = ['MthCalDt']
factor_col = ['mom_12','mom_6', 'vol_12', 'vol_6', 'rev_1', 'rvol_1',"rsi_6", 'trend_strength']
market_col = [ 'qmj_safety','seas_11_15na',
              'ret_3_1', 'iskew_ff3_21d', 'rskew_21d', 'sti_gr1a','earnings_variability', 'nfna_gr1a',
              'seas_16_20an', 'corr_1260d']
fin_col = ['capxy', 'chechy', 'cshfdy', 'cshpry', 'dltry', 'dpcy',
       'epspxy', 'oibdpy', 'txty']

# %%
stock_data = crsp.dropna().reset_index(drop=True)

# %%
def next_return(group):

  group["pred_ret"] = (group["MthRet"]).shift(-1)

  return group

stock_data = crsp.groupby("PERMNO").apply(next_return).reset_index(drop=True)

# %%
stock_data["pred_cat"] =(stock_data['pred_ret'] > 0).astype(int)

# %%
stock_data.dropna(inplace=True)
stock_data = stock_data.reset_index(drop=True)

# %%
stock_data
# Out:
#          PERMNO     cusip Ticker TradingSymbol  PERMCO  SICCD   NAICS  \
# 0         10001  36720410   EWST          EWST    7953   4920       0
# 1         10001  36720410   EWST          EWST    7953   4920       0
# 2         10001  36720410   EWST          EWST    7953   4920       0
# 3         10001  36720410   EWST          EWST    7953   4920       0
# 4         10001  36720410   EWST          EWST    7953   4920       0
# ...         ...       ...    ...           ...     ...    ...     ...
# 1637968   93436  88160R10   TSLA          TSLA   53453   9999  336110
# 1637969   93436  88160R10   TSLA          TSLA   53453   9999  336110
# 1637970   93436  88160R10   TSLA          TSLA   53453   9999  336110
# 1637971   93436  88160R10   TSLA          TSLA   53453   9999  336110
# 1637972   93436  88160R10   TSLA          TSLA   53453   9999  336110
#
#            MthCalDt    MthRet    sprtrn  ...     dltry      dpcy  epspxy  \
# 0        2004-01-30  0.010084  0.017276  ...     0.000     2.178    0.11
# 1        2004-02-27  0.079867  0.012209  ...     0.000     2.178    0.11
# 2        2004-03-31  0.117103 -0.016359  ...     0.000     2.178    0.11
# 3        2004-04-30 -0.012414 -0.016791  ...     0.697     3.468   -0.21
# 4        2004-05-28 -0.079609  0.012083  ...     0.697     3.468   -0.21
# ...             ...       ...       ...  ...       ...       ...     ...
# 1637968  2024-07-31  0.172781  0.011321  ...  2074.000  3872.000    1.51
# 1637969  2024-08-30 -0.077390  0.022835  ...  2074.000  3872.000    1.51
# 1637970  2024-09-30  0.221942  0.020197  ...  2074.000  3872.000    1.51
# 1637971  2024-10-31 -0.045025 -0.009897  ...  2881.000  5368.000    2.23
# 1637972  2024-11-29  0.381469  0.057301  ...  2881.000  5368.000    2.23
#
#             oibdpy      txty  year     rsi_6  trend_strength  pred_ret  \
# 0            3.678     0.151  2004 -0.331501        0.276062  0.079867
# 1            3.678     0.151  2004 -0.516976        0.245077  0.117103
# 2            3.678     0.151  2004  0.372631       -0.052288 -0.012414
# 3            3.520    -0.369  2004  0.781555        0.384911 -0.079609
# 4            3.520    -0.369  2004  0.596783       -0.219195  0.010622
# ...            ...       ...   ...       ...             ...       ...
# 1637968  10042.000  1403.000  2024  0.690457       -0.132221 -0.077390
# 1637969  10042.000  1403.000  2024  0.345025       -0.170373  0.221942
# 1637970  10042.000  1403.000  2024  0.807894        0.045601 -0.045025
# 1637971  13128.000  1837.000  2024  0.742569        0.244026  0.381469
# 1637972  13128.000  1837.000  2024  0.845272        0.437689  0.170008
#
#          pred_cat
# 0               1
# 1               1
# 2               0
# 3               0
# 4               1
# ...           ...
# 1637968         0
# 1637969         1
# 1637970         0
# 1637971         1
# 1637972         1
#
# [1637973 rows x 45 columns]

# %%
"""
def smart_standardization(df = stock_data, factor_cols = factor_col+fin_col,
                          market_cols = market_col,date_col='date'):

    df_processed = df.copy()
    df_processed[date_col] = pd.to_datetime(df_processed[date_col])

    for date in df_processed[date_col].unique():
        date_mask = df_processed[date_col] == date

        for factor in factor_cols:
            if factor in factor_cols:
                factor_values = df_processed.loc[date_mask, factor]
                mean_val = factor_values.mean()
                std_val = factor_values.std()

                if std_val > 0:
                    df_processed.loc[date_mask, factor] = (factor_values - mean_val) / std_val

    for factor in market_cols:
          scaler = StandardScaler()
          df_processed[factor] = scaler.fit_transform(df_processed[[factor]]).flatten()

    return df_processed

stock_data =  smart_standardization()
"""
# Out:
# "\ndef smart_standardization(df = stock_data, factor_cols = factor_col+fin_col,\n                          market_cols = market_col,date_col='date'):\n\n    df_processed = df.copy()\n    df_processed[date_col] = pd.to_datetime(df_processed[date_col])\n\n    for date in df_processed[date_col].unique():\n        date_mask = df_processed[date_col] == date\n\n        for factor in factor_cols:\n            if factor in factor_cols:\n                factor_values = df_processed.loc[date_mask, factor]\n                mean_val = factor_values.mean()\n                std_val = factor_values.std()\n\n                if std_val > 0:\n                    df_processed.loc[date_mask, factor] = (factor_values - mean_val) / std_val\n\n    for factor in market_cols:\n          scaler = StandardScaler()\n          df_processed[factor] = scaler.fit_transform(df_processed[[factor]]).flatten()\n\n    return df_processed\n\nstock_data =  smart_standardization()\n"

# %%
stock_data['Quarter'] = pd.to_datetime(stock_data['date']).dt.quarter
stock_data['Quarter'] = stock_data['Quarter'].astype('category')
stock_data["year"] = pd.to_datetime(stock_data['date']).dt.year
stock_data['naics'] = stock_data['NAICS'].astype('category')

# %%
stock_data["ind_1"] = (stock_data["SICCD"]//1000).astype("category")

# %%
stock_data.to_csv('/content/drive/MyDrive/final_data.csv', index=False)
